# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Quick look at the dataset produced by `intelligence/pipeline/make_sample.py`.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import matplotlib.pyplot as plt

from intelligence.pipeline import config
from intelligence.pipeline.preprocessing import Preprocessor

preprocessor = Preprocessor()
df = preprocessor.clean(preprocessor.load())
df.shape

# %%
df[config.LABEL_COLUMN].value_counts(normalize=True)

# %%
df[["Time", "Amount"]].describe()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for label, group in df.groupby(config.LABEL_COLUMN):
    ax.hist(group["Amount"].clip(upper=500), bins=40, alpha=0.6, label=f"Class {label}")
ax.set_xlabel("Amount (clipped at 500)")
ax.set_ylabel("Count")
ax.legend()
ax.set_title("Amount distribution by class")
plt.show()
